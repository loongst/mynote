# %%
import os
nuclei=os.listdir("nuclei-templates-9.9.0")
nuclei
# Out:
# ['.github',
#  '.gitignore',
#  '.new-additions',
#  '.nuclei-ignore',
#  '.pre-commit-config.yml',
#  '.yamllint',
#  'cloud',
#  'code',
#  'CODE_OF_CONDUCT.md',
#  'CONTRIBUTING.md',
#  'contributors.json',
#  'cves.json',
#  'cves.json-checksum.txt',
#  'dast',
#  'dns',
#  'file',
#  'headless',
#  'helpers',
#  'http',
#  'javascript',
#  'LICENSE.md',
#  'network',
#  'passive',
#  'profiles',
#  'PULL_REQUEST_TEMPLATE.md',
#  'README.md',
#  'README_KR.md',
#  'ssl',
#  'templates-checksum.txt',
#  'TEMPLATES-STATS.json',
#  'TEMPLATES-STATS.md',
#  'TOP-10.md',
#  'wappalyzer-mapping.yml',
#  'workflows']

# %% [markdown]
# 找到kval值为空poc，放到当前目录下的kval文件夹里

# %%
import shutil
import re
regxfind=re.compile(r"kval:\s{0,6}\n\s{6}-")
regx=re.compile(r"")
def Traversal_file():
    for root,dirs,files in os.walk("nuclei-templates-9.9.0"):
        # for dir in list(dirs):
        #     if dir in self.dir_to_exclude.split(","):
        #         dirs.remove(dir)
        #         shutil.rmtree(dir)
        #         continue

        for file in files:
            # print(file)
            if file.endswith("yml") or file.endswith("yaml"):
                abpath=os.path.join(root,file)
                content=""
                with open(abpath,"r+",encoding="utf-8") as f:
                    content=f.read()
                # if "- type: kval" in content:
                #     shutil.copy(abpath,"./kval/")

                # xx=re.findall(regxfind,content)
                # if xx:
                #     shutil.copy(abpath,"./kval2/")

                if "- type: xpath" in content:
                    shutil.copy(abpath,"./fxpath/")
                

Traversal_file()

# %% [markdown]
# 替换kval目录下kval值为空的项

# %%
import re 
import os
regx=re.compile(r"\s{6}-\stype:\skval\n\s{8}kval:\n")
# regxfind=re.compile(r"kval:\s{0,6}\n\s{6}-")
for i in os.listdir("kval"):
    with open("kval/{}".format(i),"+r",encoding="utf-8") as f1,open("kval/{}.bak".format(i),"+w",encoding="utf-8") as f2:
        con=f1.read()
        new=re.sub(regx,"",con)
        print(new)
        f2.write(new)
    os.remove("kval/{}".format(i))
    os.rename("kval/{}.bak".format(i),"kval/{}".format(i))
# Out:
# id: CVE-2021-44228
# info:
#   name: Apache Log4j2 Remote Code Injection
#   author: melbadry9,dhiyaneshDK,daffainfo,anon-artist,0xceba,Tea,j4vaovo
#   severity: critical
#   description: |
#     Apache Log4j2 <=2.14.1 JNDI features used in configuration, log messages, and parameters do not protect against attacker controlled LDAP and other JNDI related endpoints. An attacker who can control log messages or log message parameters can execute arbitrary code loaded from LDAP servers when message lookup substitution is enabled.
#   impact: |
#     Successful exploitation of this vulnerability can lead to remote code execution, potentially compromising the affected system.
#   remediation: Upgrade to Log4j 2.3.1 (for Java 6), 2.12.3 (for Java 7), or 2.17.0 (for Java 8 and later).
#   reference:
#     - https://logging.apache.org/log4j/2.x/security.html
#     - https://nvd.nist.gov/vuln/detail/CVE-2021-44228
#     - https://github.com/advisories/GHSA-jfh8-c2jp-5v3q
# ...

# %% [markdown]
# 以下尝试文件自动分类
# 1、先删除无用的文件和目录

# %%
import os 
import json
import yaml

path=r"D:\github_repo\test\nuclei-templates-9.9.0"

kk=10
for root,dirs,files in os.walk(path):
    if not "helpers" in root:
        
        for file in files:
            abpath=os.path.join(root,file)
            delfile=""
            if not file.endswith("yaml") and not file.endswith("yml") and not file.startswith("."):
                print(abpath)
                os.remove(abpath)
                continue
            else:
                with open(abpath,"r+",encoding="utf-8") as f:
                    data=f.read()
                    json_template = yaml.load(data, Loader=yaml.FullLoader)
                    
                    if not json_template.get("http") and not json_template.get("tcp"):
                        delfile=abpath
                if delfile:
                    print(delfile)
                    os.remove(delfile)
            print("-"*100)


for root,dirs,files in os.walk(path):
    for dir in dirs:
        dirpath = os.path.join(root, dir)
        try:
            # 如果目录为空，则删除它
            os.rmdir(dirpath)
            print(f"Removed empty directory: {dirpath}")
        except OSError as e:
            # 如果目录不为空或者无法删除，则打印错误信息
            print(f"Error: {e.strerror} {dirpath}")
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# from pocsuite3.lib.yaml.nuclei.templates import Template
import binascii
import json
import re
import yaml
yaml_template = r"D:\github_repo\test\nuclei-templates-9.9.0\dns\DNS-DMARC-Detect.yaml"

with open(yaml_template,"r+",encoding="utf-8") as f:
    data=f.read()
    # print(data)
    json_template = yaml.load(data, Loader=yaml.FullLoader)

    print(json_template)
    if json_template.get("id"):
        print("1")
    else:
        print("xxxxxxx")
# Out:
# {'id': 'dmarc-detect', 'info': {'name': 'DNS DMARC - Detect', 'author': 'juliosmelo', 'severity': 'info', 'description': 'DNS DMARC information was detected.\n', 'reference': ['https://dmarc.org/', 'https://dmarc.org/wiki/FAQ#Why_is_DMARC_important.3F'], 'classification': {'cvss-metrics': 'CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:N', 'cvss-score': 0, 'cwe-id': 'CWE-200'}, 'metadata': {'max-request': 1}, 'tags': 'dns,dmarc'}, 'dns': [{'name': '_dmarc.{{FQDN}}', 'type': 'TXT', 'matchers': [{'type': 'regex', 'part': 'answer', 'regex': ['IN\tTXT\\t(.+DMARC.+)$']}], 'extractors': [{'type': 'regex', 'group': 1, 'regex': ['IN\tTXT\t(.+DMARC.+)']}]}]}
# 1

# %% [markdown]
# 尝试将poc分类

# %%
full_list=[]
for root,dirs,files in os.walk(path):
    if not "helpers" in root:
        if files:
            full_list.extend(files)
len(full_list)
# Out:
# 7754

# %%
new_list=[[x] for x in full_list]
new_list
# Out:
# [['AWS-Apps-Cloud-Enumeration.yaml'],
#  ['AWS-S3-Buckets-Cloud-Enumeration.yaml'],
#  ['Azure-Websites-Cloud-Enumeration.yaml'],
#  ['GCP-App-Engine-(Appspot)-Cloud-Enumeration.yaml'],
#  ['GCP-Buckets-Cloud-Enumeration.yaml'],
#  ['GCP-Firebase-Apps-Cloud-Enumeration.yaml'],
#  ['GCP-Firebase-Realtime-Database-Cloud-Enumeration.yaml'],
#  ['OwnCloud-WebDAV-API-Authentication-Bypass-(CVE-2023-49105).yaml'],
#  ['PHP-imap-Remote-Command-Execution-(CVE-2018-19518).yaml'],
#  ['Apache-Log4j2-Remote-Code-Injection-(CVE-2021-45046-DAST).yaml'],
#  ['Django-SQL-injection-(CVE-2022-34265).yaml'],
#  ['Text4Shell-Remote-Code-Execution-(CVE-2022-42889).yaml'],
#  ['Blind-OS-Command-Injection.yaml'],
#  ['Ruby-Kernel#openURI.open-RCE.yaml'],
#  ['crlf-injection.yaml'],
#  ['Parameter-based-cookie-injection.yaml'],
#  ['LFI-Detection-Keyed.yaml'],
#  ['Local-File-Inclusion-Linux.yaml'],
#  ['Local-File-Inclusion-Windows.yaml'],
#  ['Open-Redirect-Detection.yaml'],
# ...

# %%
# import csv

# fieldnames = ['fileName']
 
# with open(r"D:\github_repo\test\data.csv", 'w+', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=fieldnames)
#     writer.writeheader()
#     writer.writerows(new_list)


with open(r"D:\github_repo\test\data2.txt","w+",encoding="utf-8") as f:
    for i in full_list:
        f.write(i+",\n")
